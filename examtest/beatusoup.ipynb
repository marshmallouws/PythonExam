# %%
import bs4
import requests
import re
from time import sleep

# %%
response = requests.get("https://genius.com/Snoop-dogg-drop-it-like-its-hot-lyrics")
print(response.status_code)
soup = bs4.BeautifulSoup(response.content, "html.parser")
comment = soup.find("div", {"class": "hwxsoX"})
result = "We couldn't find much buzz about this song :(" if comment is None else re.sub(r'^https?:\/\/.*[\r\n]*', '', comment.getText(), flags=re.MULTILINE)
print(result)

print(soup.prettify())
# Out:
# 200
# The phrase “Drop it like it’s hot” existed in hip-hop for many years before this song—but Snoop and Pharrell undoubtedly brought it to new heights when this became Snoop’s first ever #1 hit on Billboard.
# Snoop and Pharrell recalled the making of this song on GGN including how Pharrell came up with the hook, what inspired the spray can sound on the beat, how P made Snoop rewrite his second verse, and how Chad Hugo added the synth drop to the beat:
# Everyone from Lil Flip to Positive K to Jay Z had used the phrase on songs before this came out, but it was made famous by a 17-year-old Lil Wayne when he uttered it on Juvenile’s 1999 smash “Back That Azz Up.” Lil Wayne later responded to this song with “Nah This Ain’t The Remix” by remaking the hook, and admitting to being a “little upset” before ultimately giving Snoop his props by paraphrasing a line from Jay Z’s “Takeover”
# Nah, I ain’t a hater, don’t get me wrong
# I made it a hot line, you made it a hot song
# This song was released as a playable track in the Rock Band game series, albeit as an alternate rock remix to better fit with the game setting.
#
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Snoop Dogg – Drop It Like It's Hot Lyrics | Genius Lyrics
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="app-id=709482991" name="apple-itunes-app"/>
#   <link href="https://assets.genius.com/images/apple-touch-icon.png?1589830181" rel="apple-touch-icon"/>
#   <link href="https://assets.genius.com/images/apple-touch-icon.png?1589830181" rel="apple-touch-icon"/>
#   <!-- Mobile IE allows us to activate ClearType technology for smoothing fonts for easy reading -->
#   <meta content="on" http-equiv="cleartype"/>
#   <meta content="f63347d284f184b0" name="y_key"/>
#   <meta content="Genius" property="og:site_name">
#    <meta content="265539304824" property="fb:app_id">
#     <meta content="308252472676410" property="fb:pages">
#      <link href="https://genius.com/opensearch.xml" rel="search" title="Genius" type="application/opensearchdescription+xml"/>
#      <script>
#       !function(){if('PerformanceLongTaskTiming' in window){var g=window.__tti={e:[]};
# g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});
# g.o.observe({entryTypes:['longtask']})}}();
#      </script>
#      <link as="script" href="https://assets.genius.com/javascripts/compiled/reactSongClient.desktop-151d9ed41fa74cb3de8c.js" rel="preload">
#       <script defer="true" src="https://assets.genius.com/javascripts/compiled/reactSongClient.desktop-151d9ed41fa74cb3de8c.js" type="text/javascript">
#       </script>
#       <link as="script" href="https://assets.genius.com/javascripts/compiled/reactVendors.desktop-cc966f5f1bfeac24665b.js" rel="preload"/>
#       <script defer="true" src="https://assets.genius.com/javascripts/compiled/reactVendors.desktop-cc966f5f1bfeac24665b.js" type="text/javascript">
#       </script>
#       <link as="script" href="https://assets.genius.com/javascripts/compiled/reactPageVendors.desktop-6c2ca354a441804b552a.js" rel="preload"/>
#       <script defer="true" src="https://assets.genius.com/javascripts/compiled/reactPageVendors.desktop-6c2ca354a441804b552a.js" type="text/javascript">
#       </script>
#       <link as="script" href="https://assets.genius.com/javascripts/compiled/reactPage.desktop-46c4763b9befb1cb65dd.js" rel="preload"/>
#       <script defer="true" src="https://assets.genius.com/javascripts/compiled/reactPage.desktop-46c4763b9befb1cb65dd.js" type="text/javascript">
#       </script>
#       <link as="script" href="https://assets.genius.com/javascripts/compiled/reactAds.desktop-bd00eaefd8344a9e9836.js" rel="preload"/>
#       <script defer="true" src="https://assets.genius.com/javascripts/compiled/reactAds.desktop-bd00eaefd8344a9e9836.js" type="text/javascript">
#       </script>
#       <style>
#        @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_bold.woff2?1589830181) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_bold.woff?1589830181) format('woff');
#     font-style: normal;
#     font-weight: bold;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_normal.woff2?1589830181) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_normal.woff?1589830181) format('woff');
#     font-style: normal;
#     font-weight: normal;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_normal_italic.woff2?1589830181) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_normal_italic.woff?1589830181) format('woff');
#     font-style: italic;
#     font-weight: normal;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(data:font/woff2;base64,...) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_light.woff?1589830181) format('woff');
#     font-style: normal;
#     font-weight: 100;
#   }
#
#   @font-face {
#     font-family: 'Programme';
#     src: url(https://assets.genius.com/fonts/programme_light_italic.woff2?1589830181) format('woff2'),
#       url(https://assets.genius.com/fonts/programme_light_italic.woff?1589830181) format('woff');
#     font-style: italic;
#     font-weight: 100;
#   }
#       </style>
#       <script defer="" src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js">
#       </script>
#       <script>
#        window['Genius.cmp'] = window['Genius.cmp'] || [];
#       </script>
#       <script>
#        (function() {
#       var _optanon;
#       var _cmp = function(method, params, callback) {
#         window['Genius.cmp'].push(function(gcmp) {
#           gcmp.__cmp_call(method, params, callback);
#         });
#       };
#
#       _cmp.receiveMessage = function(event) {
#         window['Genius.cmp'].push(function(gcmp) {
#           gcmp.handle_post_message(event);
#         });
#       };
#
#       Object.defineProperties(window, {
#         __cmp: {
#           get: function() {
#             return _cmp;
#           }
#         },
#         Optanon: {
#           set: function(optanon) {
#             window['Genius.cmp'].push(function(gcmp) {
#               gcmp.resolve_with_optanon(optanon);
#             });
#             _optanon = optanon;
#           },
#
#           get: function() {
#             return _optanon;
#           }
#         }
#       });
#     })();
#       </script>
#       <script defer="true" src="https://cdn.cookielaw.org/consent/6f0fd677-f230-419d-b02c-9f05ec24d682.js" type="text/javascript">
#       </script>
#       <script defer="true" src="https://assets.genius.com/javascripts/compiled/cmp-eb69b1662611d49c614f.js" type="text/javascript">
#       </script>
#       <!--sse-->
#       <script>
#        window['Genius.ads'] = window['Genius.ads'] || [];
#       </script>
#       <script async="true" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#       </script>
#       <script>
#        !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#       </script>
#       <script>
#        window['Genius.ads'].push(function(ads) {
#       var config = {"ad_placements":{"amp_article_sticky":{"sizes":[[300,50],[320,50]],"a9":true,"kv":{"is_atf":false}},"amp_article_footer":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_article_footer_prebid"}}]},"amp_album_sticky":{"sizes":[[320,50]],"a9":true,"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_album_sticky_prebid"}}]},"amp_album_footer":{"sizes":[[300,250]],"a9":true,"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_mw_album_footer_prebid"}}]},"amp_song_annotation":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294868"}},{"bidder":"ix","params":{"id":10,"siteID":194719}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613918"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_annotation_prebid"}}]},"amp_song_below_player":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"triplelift","params":{"inventoryCode":"amp_song_below_player_prebid"}}]},"amp_song_below_song_bio":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294916"}},{"bidder":"ix","params":{"id":8,"siteID":194716}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613910"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_below_song_bio_prebid"}}]},"amp_song_leaderboard":{"sizes":[[320,50]],"a9":true,"kv":{"is_atf":true},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"13937404"}},{"bidder":"ix","params":{"id":25,"siteID":300787}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"1051268"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_leaderboard_prebid"}}]},"amp_song_medium1":{"sizes":[[300,250],[320,480]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294891"}},{"bidder":"ix","params":{"id":1,"siteID":194712}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613900"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium1_prebid"}}]},"amp_song_medium2":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294897"}},{"bidder":"ix","params":{"id":5,"siteID":194713}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613902"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium2_prebid"}}]},"amp_song_medium3":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294900"}},{"bidder":"ix","params":{"id":6,"siteID":194714}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613906"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium3_prebid"}}]},"amp_song_medium_footer":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294876"}},{"bidder":"ix","params":{"id":7,"siteID":194715}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613908"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_medium_footer_prebid"}}]},"amp_song_q_and_a":{"sizes":[[300,250]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294908"}},{"bidder":"ix","params":{"id":11,"siteID":194720}},{"bidder":"rubicon","params":{"accountId":"15874","siteId":"107816","zoneId":"613920"}},{"bidder":"triplelift","params":{"inventoryCode":"amp_song_q_and_a_prebid"}}]},"amp_song_sticky":{"sizes":[[300,50],[320,50]],"a9":true,"kv":{"is_atf":false},"prebid_placements":[{"bidder":"appnexus","params":{"placementId":"11294881"}},{"bidder":"ix","params":{"id":3,"siteID":194711}},{"bidder": ...
#       var targeting_list = [{"name":"song_id","values":["1113"]},{"name":"song_title","values":["Drop It Like Its Hot"]},{"name":"artist_id","values":["46"]},{"name":"artist_name","values":["Snoop Dogg"]},{"name":"is_explicit","values":["true"]},{"name":"pageviews","values":["524089"]},{"name":"primary_tag_id","values":["1434"]},{"name":"primary_tag","values":["rap"]},{"name":"tag_id","values":["798","2607","261","1434"]},{"name":"song_tier","values":["D"]},{"name":"topic","values":["weed"]},{"name":"has_song_story","values":["false"]},{"name":"in_top_10","values":["false"]},{"name":"artist_in_top_10","values":["false"]},{"name":"album_in_top_10","values":["false"]},{"name":"new_release","values":["false"]},{"name":"release_month","values":["200409"]},{"name":"release_year","values":["2004"]},{"name":"release_decade","values":["2000"]},{"name":"in_top_10_pop","values":["false"]},{"name":"in_top_10_rap","values":["false"]},{"name":"in_top_10_rock","values":["false"]},{"name":"in_top_10_country","values":["false"]},{"name":"in_top_10_r_and_b","values":["false"]},{"name":"environment","values":["production"]},{"name":"platform","values":["web"]},{"name":"ad_page_type","values":["song"]}];
#       var initial_units = ["desktop_song_combined_leaderboard","desktop_song_lyrics_sidebar"];
#       var targeting = {};
#       targeting_list.forEach(function(pair) {
#         targeting[pair.name] = pair.values;
#       });
#       var initial_last_reset_at = 1 || Date.now();
#
#       ads.initialize({config: config, targeting: targeting, initial_units: initial_units, initial_last_reset_at: initial_last_reset_at});
#
#         initial_units.forEach(unit => ads.render(unit, unit));
#
#     });
#       </script>
#       <script async="" src="https://cdn.adsafeprotected.com/iasPET.1.js">
#       </script>
#       <!--/sse-->
#       <style data-styled="true" data-styled-version="5.1.0">
#        .hwxsoX{word-wrap:break-word;word-break:break-word;font:100 1rem/1.5 'Programme',sans-serif;}/*!sc*/
# .hwxsoX h1{font-size:1.5rem;}/*!sc*/
# .hwxsoX h2{font-size:1.25rem;}/*!sc*/
# .hwxsoX h3{font-size:1.125rem;}/*!sc*/
# .hwxsoX h4,.hwxsoX h5,.hwxsoX h6{font-size:1rem;}/*!sc*/
# .hwxsoX h1,.hwxsoX h2,.hwxsoX h3,.hwxsoX h4,.hwxsoX h5,.hwxsoX h6{font-family:'Programme',sans-serif;font-weight:600;margin:1rem 0 0;}/*!sc*/
# .hwxsoX a{color:#000;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hwxsoX p{margin:1rem 0;}/*!sc*/
# .hwxsoX p:empty{display:none;}/*!sc*/
# .hwxsoX small{font-size:.75rem;}/*!sc*/
# .hwxsoX img{display:block;height:auto;margin-left:auto;margin-right:auto;max-height:325px;width:auto;}/*!sc*/
# .hwxsoX blockquote{margin:1rem 0 0 .5rem;padding-left:1rem;position:relative;display:block;}/*!sc*/
# .hwxsoX blockquote:before{content:'\201C';position:absolute;top:-.1em;left:-0.3em;font:bold 2.25rem/1 "Times New Roman";color:inherit;opacity:.75;}/*!sc*/
# .hwxsoX pre{font-family:inherit;margin:1rem 0;}/*!sc*/
# .hwxsoX code{font-family:'Consolas','Monaco','Lucida Console','Liberation Mono','DejaVu Sans Mono','Bitstream Vera Sans Mono','Courier New',monospace;font-size:.75rem;}/*!sc*/
# .hwxsoX table{margin:1rem 0;width:100%;}/*!sc*/
# .hwxsoX th,.hwxsoX td{padding:.5rem .5rem 0;}/*!sc*/
# .hwxsoX th{border-bottom:1px solid #e9e9e9;font-weight:bold;text-align:left;}/*!sc*/
# .hwxsoX ul,.hwxsoX ol{list-style-type:none;margin:1rem 0;padding:0;}/*!sc*/
# .hwxsoX ul ul,.hwxsoX ol ul,.hwxsoX ul ol,.hwxsoX ol ol{margin:0;padding:0 0 0 1rem;}/*!sc*/
# .hwxsoX ul li,.hwxsoX ol li{padding-left:1.6em;position:relative;}/*!sc*/
# .hwxsoX ul li:before{content:'\2022';left:calc(1.6em / 2.5);position:absolute;}/*!sc*/
# .hwxsoX ol{counter-reset:ordered_list_counter;}/*!sc*/
# .hwxsoX ol li:before{font-feature-settings:'tnum';content:counter(ordered_list_counter) '. ';counter-increment:ordered_list_counter;left:-.5rem;position:absolute;text-align:right;width:1.6em;}/*!sc*/
# .hwxsoX dd{margin:0 0 0 1rem;}/*!sc*/
# .hwxsoX hr{border:1px solid #e9e9e9;border-width:1px 0 0;}/*!sc*/
# .hwxsoX iframe{max-width:100%;}/*!sc*/
# .hwxsoX .embedly_preview{font-size:1rem;margin-top:1rem;margin-bottom:1rem;}/*!sc*/
# .hwxsoX .embedly_preview .gray_container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;word-wrap:break-word;word-break:break-word;}/*!sc*/
# .hwxsoX .embedly_preview a{font-weight:bold;}/*!sc*/
# .hwxsoX .embedly_preview iframe{display:block;margin:auto;width:100%;}/*!sc*/
# .hwxsoX .embedly_preview--video{position:relative;width:100%;height:0;padding-bottom:56.25%;}/*!sc*/
# .hwxsoX .embedly_preview--video iframe{position:absolute;top:0;left:0;width:100%;height:100%;}/*!sc*/
# .hwxsoX .embedly_preview-thumb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:1rem;max-height:6rem;overflow:hidden;}/*!sc*/
# .hwxsoX .embedly_preview-thumb img{display:block;height:100%;object-fit:cover;width:100%;}/*!sc*/
# .hwxsoX .embedly_preview-text{-webkit-flex:3;-ms-flex:3;flex:3;color:#9a9a9a;line-height:1.5em;}/*!sc*/
# .hwxsoX .embedly_preview-description{display:-webkit-box;-webkit-line-clamp:3;-webkit-box-orient:vertical;max-height:4.5em;overflow:hidden;}/*!sc*/
# data-styled.g1[id="RichText__Container-oz284w-0"]{content:"hwxsoX,"}/*!sc*/
# .pxPBq{position:relative;padding-bottom:100%;background:#e9e9e9;background-size:cover;}/*!sc*/
# .jeFYl{position:relative;width:32px;height:32px;background:#e9e9e9;background-size:cover;}/*!sc*/
# data-styled.g25[id="SizedImage__Container-sc-1hyeaua-0"]{content:"pxPBq,jeFYl,"}/*!sc*/
# .hYJUSb{position:absolute;width:100%;height:100%;object-fit:cover;}/*!sc*/
# data-styled.g26[id="SizedImage__NoScript-sc-1hyeaua-1"]{content:"hYJUSb,"}/*!sc*/
# .evnPtg{font-size:.75rem;font-weight:100;line-height:1;-webkit-letter-spacing:1px;-moz-letter-spacing:1px;-ms-letter-spacing:1px;letter-spacing:1px;text-transform:capitalize;color:#000;}/*!sc*/
# .gaIRh{font-size:.75rem;font-weight:400;line-height:1;-webkit-letter-spacing:1px;-moz-letter-spacing:1px;-ms-letter-spacing:1px;letter-spacing:1px;text-transform:uppercase;color:#fff;}/*!sc*/
# data-styled.g30[id="TextLabel-sc-8kw9oj-0"]{content:"evnPtg,gaIRh,"}/*!sc*/
# .dluqjZ svg{display:block;fill:none;height:2.25rem;margin:auto;stroke:#9a9a9a;stroke-width:.05rem;width:2.25rem;height:36px;width:36px;}/*!sc*/
# .dluqjZ svg circle{-webkit-animation:hFBEL 2s ease-out infinite;animation:hFBEL 2s ease-out infinite;}/*!sc*/
# data-styled.g34[id="PlaceholderSpinner__Container-r4gz6r-0"]{content:"dluqjZ,"}/*!sc*/
# .cziiuX svg{display:block;height:22px;fill:#fff;}/*!sc*/
# .fRTMWj svg{display:block;height:19px;fill:#fff;}/*!sc*/
# data-styled.g69[id="SocialLinks__Link-jwyj6b-1"]{content:"cziiuX,fRTMWj,"}/*!sc*/
# .iuNSEV{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .iuNSEV .SocialLinks__Link-jwyj6b-1 + .SocialLinks__Link-jwyj6b-1{margin-left:1.5rem;}/*!sc*/
# data-styled.g70[id="SocialLinks__Container-jwyj6b-2"]{content:"iuNSEV,"}/*!sc*/
# .uGviF{font-size:2.25rem;font-weight:100;line-height:1.125;margin-bottom:2.25rem;}/*!sc*/
# data-styled.g75[id="PageFooterSocial__Slogan-sc-14u22mq-0"]{content:"uGviF,"}/*!sc*/
# .kTXFZQ{display:block;color:inherit;margin:0 .25rem;}/*!sc*/
# data-styled.g76[id="PageFooterArtistLinks__Link-sc-1ng9ih0-0"]{content:"kTXFZQ,"}/*!sc*/
# .fWkWhX{display:block;color:inherit;font-weight:100;cursor:pointer;}/*!sc*/
# data-styled.g77[id="PageFooterdesktop__Link-hz1fx1-0"]{content:"fWkWhX,"}/*!sc*/
# .jeXtB{display:grid;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;grid-template-columns:[grid-start] repeat(3,minmax(14px,44px)) [center-start] repeat(6,minmax(14px,44px)) [center-end] repeat(3,minmax(14px,44px)) [grid-end];grid-column-gap:60px;grid-row-gap:40px;background:#121212;color:#fff;padding:3rem 60px 2.25rem;}/*!sc*/
# .jeXtB .PageFooterdesktop__Link-hz1fx1-0 + .PageFooterdesktop__Link-hz1fx1-0{margin-top:1rem;}/*!sc*/
# data-styled.g78[id="PageFooterdesktop__Section-hz1fx1-1"]{content:"jeXtB,"}/*!sc*/
# .ezETfi{grid-column:span 6;}/*!sc*/
# data-styled.g79[id="PageFooterdesktop__Half-hz1fx1-2"]{content:"ezETfi,"}/*!sc*/
# .kxemmA{grid-column:span 3;}/*!sc*/
# data-styled.g80[id="PageFooterdesktop__Quarter-hz1fx1-3"]{content:"kxemmA,"}/*!sc*/
# .kwefgy{grid-column:span 3;grid-column:7 / span 3;}/*!sc*/
# data-styled.g81[id="PageFooterdesktop__OffsetQuarter-hz1fx1-4"]{content:"kwefgy,"}/*!sc*/
# .hYXrZf{display:block;color:#9a9a9a;font-weight:100;font-size:.625rem;}/*!sc*/
# data-styled.g82[id="PageFooterdesktop__FinePrint-hz1fx1-5"]{content:"hYXrZf,"}/*!sc*/
# .hdvOOl{display:grid;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;grid-template-columns:[grid-start] repeat(3,minmax(14px,44px)) [center-start] repeat(6,minmax(14px,44px)) [center-end] repeat(3,minmax(14px,44px)) [grid-end];grid-column-gap:60px;grid-row-gap:40px;background:#121212;color:#fff;padding:3rem 60px 2.25rem;border-top:.15rem solid #2a2a2a;padding-top:2.25rem;padding-bottom:2.25rem;}/*!sc*/
# .hdvOOl .PageFooterdesktop__Link-hz1fx1-0 + .PageFooterdesktop__Link-hz1fx1-0{margin-top:1rem;}/*!sc*/
# data-styled.g83[id="PageFooterdesktop__Bottom-hz1fx1-6"]{content:"hdvOOl,"}/*!sc*/
# .bratAU{grid-column:span 3;color:inherit;}/*!sc*/
# data-styled.g84[id="PageFooterdesktop__VerifiedArtists-hz1fx1-7"]{content:"bratAU,"}/*!sc*/
# .biAwJZ{grid-column:span 9;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g85[id="PageFooterdesktop__Artists-hz1fx1-8"]{content:"biAwJZ,"}/*!sc*/
# .dJPobE{margin-right:1rem;}/*!sc*/
# data-styled.g86[id="PageFooterdesktop__ArtistsLabel-hz1fx1-9"]{content:"dJPobE,"}/*!sc*/
# .kthwUN{background:#e9e9e9;line-height:0;}/*!sc*/
# .hpiJis{width:300px;height:250px;background:#e9e9e9;line-height:0;}/*!sc*/
# .kaniyY{width:728px;height:90px;background:#e9e9e9;line-height:0;}/*!sc*/
# data-styled.g88[id="DfpAd__Container-sc-1tnbv7f-0"]{content:"kthwUN,hpiJis,kaniyY,"}/*!sc*/
# .dIgauN{width:100%;}/*!sc*/
# data-styled.g99[id="LeaderboardOrMarquee__Sticky-yjd3i4-0"]{content:"dIgauN,"}/*!sc*/
# .cXvCRB{position:relative;}/*!sc*/
# data-styled.g104[id="SongPage__Section-sc-19xhmoi-3"]{content:"cXvCRB,"}/*!sc*/
# .cMgFGV{position:absolute;top:calc(-1 * (undefined + 41px));}/*!sc*/
# data-styled.g105[id="SongPage__SectionAnchor-sc-19xhmoi-4"]{content:"cMgFGV,"}/*!sc*/
# .DGVcp{display:grid;grid-template-columns: [grid-start] 0.75rem [lyric-start] 5rem [section-start] repeat(4,5rem) [section-end] 5rem [lyric-end] 1fr [grid-end];grid-gap:0.75rem;padding-left:0.75rem;padding-right:0.75rem;}/*!sc*/
# @media screen and (min-width:1188px){.DGVcp{grid-template-columns: [grid-start] 1fr [lyric-start] 5rem [section-start] repeat(4,5rem) [section-end] 5rem [lyric-end] 1fr [grid-end];}}/*!sc*/
# data-styled.g106[id="SongPageGrid-sc-1vi6xda-0"]{content:"DGVcp,"}/*!sc*/
# .fyFyzZ{grid-template-columns: 0.75rem [header-left-start] repeat(2,1fr) [header-center-start] repeat(3,1fr) [header-center-end] repeat(1,1fr) [header-right-start] repeat(4,1fr) [header-end] 0.75rem;background-image:linear-gradient(#fff,#e9e9e9);padding-top:1.75rem;padding-bottom:calc(3 * 0.75rem);position:relative;}/*!sc*/
# @media screen and (min-width:1188px){.fyFyzZ{grid-template-columns: 0.75rem [header-left-start] 1fr [header-center-start] repeat(4,5rem) [header-right-start] repeat(2,5rem) [header-end] 1fr;}}/*!sc*/
# data-styled.g107[id="SongHeader__Container-sc-1b7aqpg-0"]{content:"fyFyzZ,"}/*!sc*/
# .kJjCaz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;width:100%;position:relative;grid-column:header-left-start / header-center-start;z-index:1;}/*!sc*/
# @media screen and (min-width:1188px){.kJjCaz{position:absolute;padding-top:1rem;}}/*!sc*/
# data-styled.g109[id="SongHeader__Left-sc-1b7aqpg-2"]{content:"kJjCaz,"}/*!sc*/
# .ROUQS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;grid-column:header-center-start / header-center-end;color:#000;}/*!sc*/
# @media screen and (min-width:1188px){.ROUQS{grid-column:header-center-start / header-right-start;}}/*!sc*/
# data-styled.g110[id="SongHeader__Center-sc-1b7aqpg-3"]{content:"ROUQS,"}/*!sc*/
# .gRMLTr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;grid-column:header-right-start / header-end;}/*!sc*/
# data-styled.g111[id="SongHeader__Right-sc-1b7aqpg-4"]{content:"gRMLTr,"}/*!sc*/
# .kifroG{-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;margin-right:calc(2 * 0.75rem);max-width:calc(23 * 0.75rem);}/*!sc*/
# @media screen and (min-width:1188px){.kifroG{width:100%;}}/*!sc*/
# data-styled.g112[id="SongHeader__CoverArtTracklistContainer-sc-1b7aqpg-5"]{content:"kifroG,"}/*!sc*/
# .fzBbdE{box-shadow:0 0 .75rem 0 rgba(0,0,0,0.05);}/*!sc*/
# data-styled.g113[id="SongHeader__CoverArt-sc-1b7aqpg-6"]{content:"fzBbdE,"}/*!sc*/
# .jQiTNQ{font-size:2rem;font-weight:400;font-feature-settings:'ss07','ss08','ss11','ss12','ss14','ss15','ss16','ss18','ss19','ss20','ss21';color:#000;line-height:1.125;max-width:calc(3.5*5rem + 3*0.75rem);}/*!sc*/
# data-styled.g114[id="SongHeader__Title-sc-1b7aqpg-7"]{content:"jQiTNQ,"}/*!sc*/
# .DYpgM{line-height:1.33;}/*!sc*/
# data-styled.g115[id="SongHeader__Artist-sc-1b7aqpg-8"]{content:"DYpgM,"}/*!sc*/
# .hKiOLl{position:absolute;width:100%;bottom:calc(undefined + 3rem);z-index:-2;}/*!sc*/
# data-styled.g116[id="SongHeader__Sentinel-sc-1b7aqpg-9"]{content:"hKiOLl,"}/*!sc*/
# .jvlKWy{font:100 1.125rem/1.5 'Programme',sans-serif;word-wrap:break-word;word-break:break-word;}/*!sc*/
# data-styled.g120[id="Lyrics__Root-sc-1ynbvzw-0"]{content:"jvlKWy,"}/*!sc*/
# .jgQsqn{grid-column:lyric-start / lyric-end;padding:1.5rem 0;}/*!sc*/
# data-styled.g122[id="Lyrics__Container-sc-1ynbvzw-2"]{content:"jgQsqn,"}/*!sc*/
# .BjqYT{padding:calc(((1.5 * 1em) - 1.125rem) / 2) 0;}/*!sc*/
# data-styled.g127[id="ReferentFragment__ClickTarget-oqvzi6-0"]{content:"BjqYT,"}/*!sc*/
# .gWpCZc{color:#000;background-color:#e9e9e9;padding-top:calc(((((1.5 * 1em) - 1.125rem) / 2) - (.125rem / 2)) - 0.75px);padding-bottom:calc(((((1.5 * 1em) - 1.125rem) / 2) - (.125rem / 2)) - 0.25px);}/*!sc*/
# data-styled.g128[id="ReferentFragment__Highlight-oqvzi6-1"]{content:"gWpCZc,"}/*!sc*/
# .iawWnS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-weight:100;font-size:.75rem;height:3rem;background-color:#fff;color:#000;position:-webkit-sticky;position:sticky;top:calc(undefined);z-index:5;}/*!sc*/
# data-styled.g148[id="StickyNav__Container-sc-1q5ye4s-0"]{content:"iawWnS,"}/*!sc*/
# .klKTfS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:1rem;}/*!sc*/
# data-styled.g149[id="StickyNav__Left-sc-1q5ye4s-1"]{content:"klKTfS,"}/*!sc*/
# .dWBBHu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:1rem;}/*!sc*/
# data-styled.g150[id="StickyNav__Right-sc-1q5ye4s-2"]{content:"dWBBHu,"}/*!sc*/
# .iyTmqp{margin-right:1.5rem;line-height:1rem;color:#000;}/*!sc*/
# .iyTmqp span{white-space:nowrap;color:#000;}/*!sc*/
# .iyTmqp:hover{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g151[id="StickyNav__SiteLink-sc-1q5ye4s-3"]{content:"iyTmqp,"}/*!sc*/
# .kZrnYi{height:3rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-left:2.25rem;}/*!sc*/
# data-styled.g152[id="StickyNav__Subnavigation-sc-1q5ye4s-4"]{content:"kZrnYi,"}/*!sc*/
# .fCsyNi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# data-styled.g155[id="HeaderMetadata__Container-sc-1p42fnf-0"]{content:"fCsyNi,"}/*!sc*/
# .LAJX{display:grid;grid-template-columns:repeat(2,1fr);-webkit-column-gap:0.75rem;column-gap:0.75rem;}/*!sc*/
# @media screen and (min-width:1188px){.LAJX{grid-template-columns:repeat(2,calc(2 * 5rem + 0.75rem));}}/*!sc*/
# data-styled.g156[id="HeaderMetadata__Grid-sc-1p42fnf-1"]{content:"LAJX,"}/*!sc*/
# .hAhJBU{font-weight:100;font-size:.75rem;line-height:1.33;margin-bottom:1.5rem;color:#000;}/*!sc*/
# .bVnuPE{font-weight:100;font-size:.75rem;line-height:1.33;margin-bottom:1.5rem;color:#000;-webkit-align-self:flex-end;-ms-flex-item-align:end;align-self:flex-end;}/*!sc*/
# data-styled.g157[id="HeaderMetadata__Section-sc-1p42fnf-2"]{content:"hAhJBU,bVnuPE,"}/*!sc*/
# .kRHnrE{display:block;line-height:1.2;font-size:.625rem;color:#000;}/*!sc*/
# data-styled.g158[id="HeaderMetadata__Label-sc-1p42fnf-3"]{content:"kRHnrE,"}/*!sc*/
# .lbWWeh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .lbWWeh > *:not(:last-child){margin-right:1.5rem;}/*!sc*/
# .lbWWeh svg{height:0.65rem;}/*!sc*/
# data-styled.g159[id="HeaderMetadata__Stats-sc-1p42fnf-4"]{content:"lbWWeh,"}/*!sc*/
# .gBcnuN svg{fill:#000;}/*!sc*/
# data-styled.g160[id="HeaderMetadata__ViewCredits-sc-1p42fnf-5"]{content:"gBcnuN,"}/*!sc*/
# .iVBWND{font-size:.75rem;font-weight:100;line-height:1.33;margin-top:3rem;-webkit-text-decoration:none;text-decoration:none;color:#000;}/*!sc*/
# @media screen and (min-width:1188px){.iVBWND{width:calc(3 * 5rem + 2 * 0.75rem);}}/*!sc*/
# .iVBWND:hover span{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g161[id="HeaderBio__Wrapper-oaxemt-0"]{content:"iVBWND,"}/*!sc*/
# .hTnuOo{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hTnuOo svg{fill:#000;}/*!sc*/
# data-styled.g162[id="HeaderBio__ViewBio-oaxemt-1"]{content:"hTnuOo,"}/*!sc*/
# .bsFzwE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding-top:1.5rem;font-size:.75rem;line-height:1.33;font-weight:100;}/*!sc*/
# @media screen and (min-width:1188px){.bsFzwE{color:#000;}}/*!sc*/
# data-styled.g163[id="HeaderTracklist__Container-sc-1qmk74v-0"]{content:"bsFzwE,"}/*!sc*/
# .Dgflc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;line-height:1.33;margin-right:.25rem;}/*!sc*/
# @media screen and (min-width:1188px){.Dgflc{width:calc(50% - 0.75rem / 2);}}/*!sc*/
# data-styled.g164[id="HeaderTracklist__AlbumWrapper-sc-1qmk74v-1"]{content:"Dgflc,"}/*!sc*/
# .kJjUm{font-size:.625rem;line-height:1.125;}/*!sc*/
# data-styled.g165[id="HeaderTracklist__AlbumLabel-sc-1qmk74v-2"]{content:"kJjUm,"}/*!sc*/
# .hxXYDz{word-break:break-word;}/*!sc*/
# data-styled.g166[id="HeaderTracklist__Album-sc-1qmk74v-3"]{content:"hxXYDz,"}/*!sc*/
# .cwPdNU{padding-top:0.75rem;}/*!sc*/
# @media screen and (min-width:1188px){.cwPdNU svg{fill:#000;}}/*!sc*/
# data-styled.g167[id="HeaderTracklist__ViewAlbum-sc-1qmk74v-4"]{content:"cwPdNU,"}/*!sc*/
# .jZbnyS svg{height:1.33em;margin-left:calc(-1em * 0.548625);vertical-align:top;}/*!sc*/
# .jZbnyS::before{content:'\2003';font-size:0.548625em;}/*!sc*/
# data-styled.g168[id="InlineSvg__Wrapper-b788hd-0"]{content:"jZbnyS,"}/*!sc*/
# .kSdVnW{font-weight:100;color:inherit;}/*!sc*/
# .cGlaEJ{font-weight:100;-webkit-text-decoration:underline;text-decoration:underline;color:inherit;}/*!sc*/
# .cGlaEJ:hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dpVWpH{font-size:.75rem;font-weight:100;-webkit-text-decoration:underline;text-decoration:underline;color:inherit;}/*!sc*/
# .dpVWpH:hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# data-styled.g169[id="Link-h3isu4-0"]{content:"kSdVnW,cGlaEJ,dpVWpH,"}/*!sc*/
# .hFVRqM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# @media screen and (min-width:1188px){.hFVRqM{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}}/*!sc*/
# .hFVRqM .desktop_song_inread_prebid_container,.hFVRqM .desktop_song_inread2_prebid_container,.hFVRqM .desktop_song_inread3_prebid_container{margin:auto !important;}/*!sc*/
# data-styled.g171[id="InreadAd__Container-sc-1pp8jgt-0"]{content:"hFVRqM,"}/*!sc*/
# .dSmfHQ{font-weight:100;background-image:linear-gradient(#fff,#e9e9e9);padding-bottom:2.25rem;}/*!sc*/
# data-styled.g172[id="About__Grid-ut4i9m-0"]{content:"dSmfHQ,"}/*!sc*/
# .eSiFpi{grid-column:section-start / section-end;text-align:center;padding-top:calc(2.25rem + .375rem);}/*!sc*/
# data-styled.g173[id="About__Container-ut4i9m-1"]{content:"eSiFpi,"}/*!sc*/
# .kdlPmS{font-size:5rem;font-weight:normal;color:#000;}/*!sc*/
# data-styled.g174[id="About__Title-ut4i9m-2"]{content:"kdlPmS,"}/*!sc*/
# .hxeGkp{background-color:transparent;border-radius:1.25rem;padding:.75rem 1.5rem .75rem 1.5rem;margin:1rem 0 .75rem 0;border:1px solid #000;font-size:1rem;color:#000;cursor:pointer;}/*!sc*/
# .hxeGkp:hover{background-color:#000;color:#fff;}/*!sc*/
# .hxeGkp:hover svg{fill:#fff;}/*!sc*/
# data-styled.g175[id="Button-sc-1874dbw-0"]{content:"hxeGkp,"}/*!sc*/
# .kJMSQk{position:relative;font-weight:100;padding:0 1.313rem 0 1.313rem;color:#000;}/*!sc*/
# data-styled.g176[id="SongInfo__Container-nekw6x-0"]{content:"kJMSQk,"}/*!sc*/
# .iRKrFW{font-size:2.25rem;font-weight:400;margin-bottom:2.25rem;line-height:1.1;}/*!sc*/
# data-styled.g177[id="SongInfo__Title-nekw6x-1"]{content:"iRKrFW,"}/*!sc*/
# .hlmwHa{font-size:.75rem;}/*!sc*/
# data-styled.g178[id="SongInfo__Label-nekw6x-2"]{content:"hlmwHa,"}/*!sc*/
# .ftrCKq{font-size:1rem;}/*!sc*/
# .ftrCKq:not(:last-child){margin-bottom:1.5rem;}/*!sc*/
# data-styled.g179[id="SongInfo__Credit-nekw6x-3"]{content:"ftrCKq,"}/*!sc*/
# .jCkLqA{position:absolute;top:calc(-1.5 * (undefined + 3rem));}/*!sc*/
# data-styled.g180[id="SongInfo__SectionAnchor-nekw6x-4"]{content:"jCkLqA,"}/*!sc*/
# .cYtdTH{position:relative;margin:1.313rem 0 1rem 0;padding-bottom:56.25%;width:100%;}/*!sc*/
# .cYtdTH iframe{position:absolute;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g181[id="MusicVideo__Container-sc-1980jex-0"]{content:"cYtdTH,"}/*!sc*/
# .ikywhQ{text-align:center;}/*!sc*/
# data-styled.g182[id="ExpandableContent__Container-sc-1165iv-0"]{content:"ikywhQ,"}/*!sc*/
# .ewOHTu{overflow:hidden;max-height:250px;-webkit-mask:linear-gradient(rgba(0,0,0,1),transparent);mask:linear-gradient(rgba(0,0,0,1),transparent);}/*!sc*/
# data-styled.g183[id="ExpandableContent__Content-sc-1165iv-1"]{content:"ewOHTu,"}/*!sc*/
# .kqeVkf{position:relative;display:grid;grid-template-columns:[grid-start] repeat(2,1fr) [grid-end];text-align:start;}/*!sc*/
# data-styled.g184[id="PrimaryAlbum__Container-cuci8p-0"]{content:"kqeVkf,"}/*!sc*/
# .bbYbaY{position:absolute;top:calc(-1.5 * (undefined + 3rem));}/*!sc*/
# data-styled.g185[id="PrimaryAlbum__SectionAnchor-cuci8p-1"]{content:"bbYbaY,"}/*!sc*/
# .fMIxkO{margin:0 3rem 2.5rem 3rem;}/*!sc*/
# data-styled.g186[id="PrimaryAlbum__CoverArt-cuci8p-2"]{content:"fMIxkO,"}/*!sc*/
# .hGGOcK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-bottom:2.5rem;}/*!sc*/
# data-styled.g187[id="PrimaryAlbum__AlbumDetails-cuci8p-3"]{content:"hGGOcK,"}/*!sc*/
# .MKFFi{font-size:1rem;color:#000;}/*!sc*/
# data-styled.g188[id="PrimaryAlbum__Title-cuci8p-4"]{content:"MKFFi,"}/*!sc*/
# .hynzjT{font-size:.75rem;color:#000;}/*!sc*/
# data-styled.g189[id="PrimaryAlbum__Artist-cuci8p-5"]{content:"hynzjT,"}/*!sc*/
# .hrORzd{margin:1.5rem 0 1.313rem 0;font-size:.75rem;color:#000;}/*!sc*/
# data-styled.g190[id="SongDescription__Contributors-sc-615rvk-0"]{content:"hrORzd,"}/*!sc*/
# .Hbxku{text-align:left;color:#000;}/*!sc*/
# data-styled.g191[id="SongDescription__Content-sc-615rvk-1"]{content:"Hbxku,"}/*!sc*/
# .vrxkS{border-bottom:1px solid #000;margin-bottom:3rem;padding-bottom:3rem;}/*!sc*/
# data-styled.g192[id="InnerSectionDivider-sc-1x4onqw-0"]{content:"vrxkS,"}/*!sc*/
# .fvEQQh{padding:2.25rem 0;}/*!sc*/
# data-styled.g193[id="Comment__Container-qhf03b-0"]{content:"fvEQQh,"}/*!sc*/
# .kwxSXq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# data-styled.g194[id="Comment__Meta-qhf03b-1"]{content:"kwxSXq,"}/*!sc*/
# .Hdlfx{font-size:.75rem;font-weight:100;}/*!sc*/
# data-styled.g195[id="Comment__Date-qhf03b-2"]{content:"Hdlfx,"}/*!sc*/
# .lbchfN{margin:2.25rem 0;}/*!sc*/
# data-styled.g196[id="Comment__Body-qhf03b-3"]{content:"lbchfN,"}/*!sc*/
# .bIlJhm{padding-bottom:1.313rem;}/*!sc*/
# data-styled.g197[id="SongComments__Grid-sc-131p4fy-0"]{content:"bIlJhm,"}/*!sc*/
# .lgbAKX{grid-column:section-start / section-end;padding-top:calc(2.25rem + .375rem);}/*!sc*/
# data-styled.g198[id="SongComments__Container-sc-131p4fy-1"]{content:"lgbAKX,"}/*!sc*/
# .iRYNUi{font-size:5rem;margin-bottom:1rem;text-align:center;}/*!sc*/
# data-styled.g200[id="SongComments__Title-sc-131p4fy-3"]{content:"iRYNUi,"}/*!sc*/
# .ldOStC{margin-top:1.313rem;padding:.5rem 0 .5rem .75rem;border:1px solid #000;font-size:1.125rem;font-weight:100;width:100%;cursor:pointer;display:block;color:inherit;}/*!sc*/
# data-styled.g201[id="SongComments__Add-sc-131p4fy-4"]{content:"ldOStC,"}/*!sc*/
# .jseJpi:not(:last-child){border-bottom:1px solid black;}/*!sc*/
# data-styled.g202[id="SongComments__CommentContainer-sc-131p4fy-5"]{content:"jseJpi,"}/*!sc*/
# .kXPNuG{text-align:center;margin-bottom:1.313rem;}/*!sc*/
# data-styled.g203[id="SongComments__ShowMore-sc-131p4fy-6"]{content:"kXPNuG,"}/*!sc*/
# .kuLlIS{overflow:hidden;max-height:480px;-webkit-mask:linear-gradient(rgba(0,0,0,1),transparent);mask:linear-gradient(rgba(0,0,0,1),transparent);}/*!sc*/
# data-styled.g204[id="SongComments__Expandable-sc-131p4fy-7"]{content:"kuLlIS,"}/*!sc*/
# .iqBkue{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-weight:100;color:inherit;}/*!sc*/
# data-styled.g205[id="UserBadge__Container-v0cw88-0"]{content:"iqBkue,"}/*!sc*/
# .KJaqJ{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;overflow:hidden;border-radius:100%;}/*!sc*/
# data-styled.g206[id="UserBadge__Avatar-v0cw88-1"]{content:"KJaqJ,"}/*!sc*/
# .iHenNx{margin-left:1rem;line-height:1;text-align:left;}/*!sc*/
# data-styled.g207[id="UserBadge__NameAndRole-v0cw88-2"]{content:"iHenNx,"}/*!sc*/
# .hPWWDF{font-size:.625rem;}/*!sc*/
# data-styled.g208[id="UserBadge__Name-v0cw88-3"]{content:"hPWWDF,"}/*!sc*/
# .icoBuC{margin-top:.25rem;font-size:.5rem;}/*!sc*/
# .icoBuC svg{margin-left:.25rem;height:7px;width:7px;stroke:#000;stroke-width:1px;fill:#fff;overflow:visible;position:relative;}/*!sc*/
# data-styled.g209[id="UserBadge__Role-v0cw88-4"]{content:"icoBuC,"}/*!sc*/
# .nHuYy{font-size:.75rem;font-weight:100;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:baseline;-webkit-box-align:baseline;-ms-flex-align:baseline;align-items:baseline;cursor:default;}/*!sc*/
# .nHuYy svg{display:block;height:1em;}/*!sc*/
# .nHuYy > *{margin-right:.75rem;}/*!sc*/
# .nHuYy > *:not(:first-child){cursor:pointer;}/*!sc*/
# .nHuYy > *:last-child{margin-right:0;}/*!sc*/
# data-styled.g210[id="VotingActions__Container-sc-1w1brao-0"]{content:"nHuYy,"}/*!sc*/
# .cKbwOl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:.75rem;color:#000;}/*!sc*/
# .cKbwOl svg{display:block;height:.65em;fill:#000;}/*!sc*/
# data-styled.g222[id="LabelWithIcon__Container-sc-1ri57wg-0"]{content:"cKbwOl,"}/*!sc*/
# .bwfvoe{-webkit-text-decoration:none;text-decoration:none;font-weight:100;font-size:.75rem;margin-left:.25rem;color:#000;}/*!sc*/
# data-styled.g223[id="LabelWithIcon__Label-sc-1ri57wg-1"]{content:"bwfvoe,"}/*!sc*/
# .eGLQob{grid-column-end:grid-end;justify-self:right;}/*!sc*/
# data-styled.g224[id="RightSidebar-pajcl2-0"]{content:"eGLQob,"}/*!sc*/
# .gzPjw{position:-webkit-sticky;position:sticky;top:calc(undefined + 3rem + 0.75rem);margin-top:0.75rem;height:100%;min-height:undefinedpx;max-height:calc(100vh - undefined + 3rem + 0.75rem);}/*!sc*/
# .bDikLl{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0.75rem 0;}/*!sc*/
# data-styled.g225[id="SidebarAd__Container-sc-1cw85h6-0"]{content:"gzPjw,bDikLl,"}/*!sc*/
# .cSKAwQ{background-color:black;padding:15px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g226[id="SectionLeaderboard__Container-sc-1pjk0bw-0"]{content:"cSKAwQ,"}/*!sc*/
# .cJGzHp{background-color:black;min-height:calc(3rem + 90px);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g227[id="Leaderboard-da326u-0"]{content:"cJGzHp,"}/*!sc*/
# .ebDctO{z-index:2;position:fixed;width:100%;bottom:0;visibility:hidden;}/*!sc*/
# data-styled.g228[id="AppleMusicPlayer__PositioningContainer-uavgzr-0"]{content:"ebDctO,"}/*!sc*/
# .ueYPW{position:absolute;bottom:0;width:100%;}/*!sc*/
# data-styled.g229[id="AppleMusicPlayer__IframeWrapper-uavgzr-1"]{content:"ueYPW,"}/*!sc*/
# .dMjlPI{grid-column:lyric-start / lyric-end;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;position:absolute;width:100%;height:calc(100% - 16px);bottom:16px;left:16px;border:2px solid #000;background:#fff;margin-left:-16px;}/*!sc*/
# data-styled.g230[id="AppleMusicPlayer__IframeWrapperLoader-uavgzr-2"]{content:"dMjlPI,"}/*!sc*/
# .bevmYM{grid-column:lyric-start / lyric-end;justify-self:end;-webkit-transition:height .2s,width .2s;transition:height .2s,width .2s;width:calc(100% + 2 * 16px);height:64px;margin-right:-16px;}/*!sc*/
# data-styled.g231[id="AppleMusicPlayer__Iframe-uavgzr-3"]{content:"bevmYM,"}/*!sc*/
# .dbzhnO{margin-left:1rem;line-height:13px;}/*!sc*/
# .dbzhnO svg{position:relative;fill:#000;top:1px;height:13px;}/*!sc*/
# data-styled.g232[id="PageHeaderLogo__Link-sc-13m4mcv-0"]{content:"dbzhnO,"}/*!sc*/
# .bcGooa{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#fff;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:calc(10 * 1rem + .75rem);height:1.5rem;}/*!sc*/
# data-styled.g233[id="PageHeaderSearch__Form-sc-4bv766-0"]{content:"bcGooa,"}/*!sc*/
# .dncEsO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;cursor:pointer;padding:0 .75rem;}/*!sc*/
# .dncEsO svg{fill:#000;width:.625rem;}/*!sc*/
# data-styled.g234[id="PageHeaderSearch__Icon-sc-4bv766-1"]{content:"dncEsO,"}/*!sc*/
# .snakD{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;position:relative;border:none;border-radius:0;background:#fff;color:#000;font-family:'Programme',sans-serif;font-feature-settings:'ss07','ss08','ss11','ss12','ss14','ss15','ss16','ss18','ss19','ss20','ss21';font-size:inherit;font-weight:inherit;line-height:inherit;-webkit-appearance:none;overflow:hidden;resize:none;outline:none;padding-left:.75rem;}/*!sc*/
# .snakD::-webkit-input-placeholder,.snakD::-webkit-input-placeholder{color:#000;font-size:.75rem;}/*!sc*/
# .snakD::-moz-placeholder,.snakD::-webkit-input-placeholder{color:#000;font-size:.75rem;}/*!sc*/
# .snakD:-ms-input-placeholder,.snakD::-webkit-input-placeholder{color:#000;font-size:.75rem;}/*!sc*/
# .snakD::placeholder,.snakD::-webkit-input-placeholder{color:#000;font-size:.75rem;}/*!sc*/
# .snakD::-ms-input-placeholder{color:#000;font-size:.75rem;}/*!sc*/
# .snakD:focus::-webkit-input-placeholder{color:#9a9a9a;font-size:.75rem;}/*!sc*/
# .snakD:focus::-moz-placeholder{color:#9a9a9a;font-size:.75rem;}/*!sc*/
# .snakD:focus:-ms-input-placeholder{color:#9a9a9a;font-size:.75rem;}/*!sc*/
# .snakD:focus::placeholder{color:#9a9a9a;font-size:.75rem;}/*!sc*/
# data-styled.g235[id="PageHeaderSearch__Input-sc-4bv766-2"]{content:"snakD,"}/*!sc*/
# .ivgTaw{position:absolute;top:calc(100vh - (undefined + 3rem));bottom:0;width:100%;z-index:-2;}/*!sc*/
# data-styled.g236[id="SectionScrollSentinel__Element-sc-1c8cvz5-0"]{content:"ivgTaw,"}/*!sc*/
# .kGJQLs{grid-column:grid-start / grid-end;text-align:start;-webkit-column-count:2;column-count:2;font-size:.75rem;}/*!sc*/
# data-styled.g237[id="AlbumTracklist__Container-sc-123giuo-0"]{content:"kGJQLs,"}/*!sc*/
# .sLeDB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:.75rem;-webkit-break-inside:avoid;break-inside:avoid;color:#000;}/*!sc*/
# data-styled.g238[id="AlbumTracklist__Track-sc-123giuo-1"]{content:"sLeDB,"}/*!sc*/
# .bPLsDz{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:relative;padding:.25rem 0;}/*!sc*/
# .guEaas{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:relative;padding:.25rem 0;}/*!sc*/
# .guEaas:after{content:'';position:absolute;top:0;right:-0.75rem;bottom:0;left:-0.75rem;border:1px solid;}/*!sc*/
# data-styled.g239[id="AlbumTracklist__TrackName-sc-123giuo-2"]{content:"bPLsDz,guEaas,"}/*!sc*/
# .epTVob{padding-right:.5rem;}/*!sc*/
# data-styled.g240[id="AlbumTracklist__TrackNumber-sc-123giuo-3"]{content:"epTVob,"}/*!sc*/
# html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;}/*!sc*/
# h1,h2,h3,h4,h5,h6{font-size:100%;font-weight:inherit;}/*!sc*/
# html{line-height:1;}/*!sc*/
# ol,ul{list-style:none;}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# caption,th,td{text-align:left;font-weight:normal;vertical-align:middle;}/*!sc*/
# q,blockquote{quotes:none;}/*!sc*/
# q:before,blockquote:before,q:after,blockquote:after{content:"";content:none;}/*!sc*/
# a img{border:none;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block;}/*!sc*/
# body{overflow-x:hidden;background-color:#fff;color:#000;font-family:'Programme',sans-serif;line-height:1.45;-webkit-text-size-adjust:100%;}/*!sc*/
# img{max-width:100%;}/*!sc*/
# li{list-style:none;}/*!sc*/
# ...
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        All Artists:
#       </span>
#      </div>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/a">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        a
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/b">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        b
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/c">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        c
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/d">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        d
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/e">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        e
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/f">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        f
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/g">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        g
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/h">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        h
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/i">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        i
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/j">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        j
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/k">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        k
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/l">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        l
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/m">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        m
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/n">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        n
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/o">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        o
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/p">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        p
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/q">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        q
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/r">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        r
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/s">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        s
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/t">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        t
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/u">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        u
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/v">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        v
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/w">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        w
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/x">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        x
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/y">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        y
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/z">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        z
#       </span>
#      </a>
#      <a class="PageFooterArtistLinks__Link-sc-1ng9ih0-0 kTXFZQ" href="/artists-index/0">
#       <span class="TextLabel-sc-8kw9oj-0 gaIRh" font-weight="normal">
#        #
#       </span>
#      </a>
#     </div>
#    </div>
#   </div>
#   <script>
#    window.__PRELOADED_STATE__ = JSON.parse('{\"currentPage\":\"songPage\",\"deviceType\":\"desktop\",\"session\":{\"cmpEnabled\":true,\"ccpaEnabled\":true,\"showAds\":true,\"logClientMetrics\":false,\"fringeEnabled\":true,\"taboolaEnabled\":false},\"songPage\":{\"song\":1113,\"paginatedComments\":{\"comments\":[2785146,1456496,3734007,3646705,2380309,2896603,1762380,3515213,4344893,4459052],\"perPage\":10,\"nextPage\":2},\"lyricsData\":{\"body\":{\"children\":[{\"children\":[{\"children\":[\"[Produced by The Neptunes]\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"2490335\"},\"attributes\":{\"href\":\"/2490335/Snoop-dogg-drop-it-like-its-hot/Produced-by-the-neptunes\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"\",{\"tag\":\"br\"},\"\",{\"children\":[\"[Refrain]\",{\"tag\":\"br\"},\"Snoop\",{\"tag\":\"br\"},\"Snoop\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"1257851\"},\"attributes\":{\"href\":\"/1257851/Snoop-dogg-drop-it-like-its-hot/Refrain-snoop-snoop\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"\",{\"tag\":\"br\"},\"[Chorus: Snoop Dogg]\",{\"tag\":\"br\"},\"\",{\"children\":[\"When the pimp\'s in the crib, ma\",{\"tag\":\"br\"},\"Drop it like it\'s hot, drop it like it\'s hot, drop it like it\'s hot\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"59912\"},\"attributes\":{\"class\":\"has_comments has_pending_edits\",\"href\":\"/59912/Snoop-dogg-drop-it-like-its-hot/When-the-pimps-in-the-crib-ma-drop-it-like-its-hot-drop-it-like-its-hot-drop-it-like-its-hot\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"When the pigs try to get at you\",{\"tag\":\"br\"},\"Park it like it\'s hot, park it like it\'s hot, park it like it\'s hot\",{\"tag\":\"br\"},\"And if a nigga get a attitude\",{\"tag\":\"br\"},\"Pop it like it\'s hot, pop it like it\'s hot, pop it like it\'s hot\",{\"tag\":\"br\"},\"I got the Rollie on my arm, and I\'m pourin\' Chandon\",{\"tag\":\"br\"},\"And \",{\"children\":[\"I roll the best weed\"],\"data\":{\"classification\":\"unreviewed\",\"editorialState\":\"pending\",\"id\":\"18273250\"},\"attributes\":{\"class\":\"has_pending_edits\",\"href\":\"/18273250/Snoop-dogg-drop-it-like-its-hot/I-roll-the-best-weed\"},\"tag\":\"a\"},\" ‘cause I got it goin\' on\",{\"tag\":\"br\"},\"\",{\"tag\":\"br\"},\"[Verse 1: Pharrell]\",{\"tag\":\"br\"},\"\",{\"children\":[\"I\'m a nice dude, with some nice dreams\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"156589\"},\"attributes\":{\"href\":\"/156589/Snoop-dogg-drop-it-like-its-hot/Im-a-nice-dude-with-some-nice-dreams\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"See these ice cubes? \",{\"children\":[\"See these Ice Creams?\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"2499349\"},\"attributes\":{\"href\":\"/2499349/Snoop-dogg-drop-it-like-its-hot/See-these-ice-creams\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"Eligible bachelor, million dollar boat\",{\"tag\":\"br\"},\"That\'s whiter than what\'s spillin\' down your throat\",{\"tag\":\"br\"},\"\",{\"children\":[\"The Phantom, exterior like fish eggs\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"42425\"},\"attributes\":{\"href\":\"/42425/Snoop-dogg-drop-it-like-its-hot/The-phantom-exterior-like-fish-eggs\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"\",{\"children\":[\"The interior like suicide wrist red\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"35302\"},\"attributes\":{\"class\":\"has_comments has_pending_edits\",\"href\":\"/35302/Snoop-dogg-drop-it-like-its-hot/The-interior-like-suicide-wrist-red\"},\"tag\":\"a\"},{\"tag\":\"br\"},\"I can exercise you, this can be your Phys. Ed\",{\"tag\":\"br\"},\"Cheat on your man, ma, that\'s how you get ahizzead\",{\"tag\":\"br\"},\"\",{\"children\":[\"Killer with the beat,\"],\"data\":{\"classification\":\"accepted\",\"editorialState\":\"accepted\",\"id\":\"621597 ...
#       window.__APP_CONFIG__ = {"env":"production","api_root_url":"/api","transform_domain":"transform.genius.com","facebook_app_id":"265539304824","facebook_opengraph_api_version":"3.2","pusher_app_key":"6d893fcc6a0c695853ac","embedly_key":"fc778e44915911e088ae4040f9f86dcd","a9_pub_id":"3459","app_store_url":"https://itunes.apple.com/us/app/genius-by-rap-genius-search/id709482991?ls=1&mt=8","play_store_url":"https://play.google.com/store/apps/details?id=com.genius.android","soundcloud_client_id":"632c544d1c382f82526f369877aab5c0","annotator_context_length":32,"comment_reasons":[{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"R","handle":"Restates the line","id":1,"name":"restates-the-line","raw_name":"restates the line","requires_body":false,"slug":"restates_the_line"},{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"S","handle":"It’s a stretch","id":2,"name":"its-a-stretch","raw_name":"it’s a stretch","requires_body":false,"slug":"its_a_stretch"},{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"M","handle":"Missing something","id":3,"name":"missing-something","raw_name":"missing something","requires_body":false,"slug":"missing_something"},{"_type":"comment_reason","context_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"…","handle":"Other","id":4,"name":"other","raw_name":"other","requires_body":true,"slug":"other"}],"comment_reasons_help_url":"https://genius.com/8846441/Genius-how-genius-works/More-on-annotations","filepicker_api_key":"Ar03MDs73TQm241ZgLwfjz","filepicker_policy":"eyJleHBpcnkiOjIzNTEwOTE1NTgsImNhbGwiOlsicGljayIsInJlYWQiLCJzdG9yZSIsInN0YXQiLCJjb252ZXJ0Il19","filepicker_signature":"68597b455e6c09bce0bfd73f758e299c95d49a5d5c8e808aaf4877da7801c4da","filepicker_s3_image_bucket":"filepicker-images-rapgenius","available_roles":["moderator","mega_boss","in_house_staff","verified_artist","meme_artist","engineer","editor","educator","staff","whitehat","tech_liaison","mediator"],"canonical_domain":"genius.com","enable_angular_debug":false,"fact_track_launch_article_url":"https://genius.com/a/genius-and-spotify-together","user_authority_roles":["moderator","editor","mediator"],"user_verification_roles":["community_artist","verified_artist","meme_artist"],"user_vote_types_for_delete":["votes","upvotes","downvotes"],"brightcove_account_id":"4863540648001","mixpanel_delayed_events_timeout":"86400","unreviewed_annotation_tooltip_info_url":"https://genius.com/8846524/Genius-how-genius-works/More-on-editorial-review","video_placements":{"desktop_song_page":[{"name":"sidebar","min_relevance":"high","fringe_min_relevance":"low","max_videos":0},{"name":"sidebar_thumb","min_relevance":"medium","fringe_min_relevance":"low","max_videos":0},{"name":"recirculated","min_relevance":"low","max_videos":3}],"mobile_song_page":[{"name":"footer","min_relevance":"medium","max_videos":1},{"name":"recirculated","min_relevance":"low","max_videos":3}],"desktop_artist_page":[{"name":"sidebar","min_relevance":"medium","fringe_min_relevance":"low","max_videos":2}],"mobile_artist_page":[{"name":"carousel","min_relevance":"medium","fringe_min_relevance":"low","max_videos":5}],"amp_song_page":[{"name":"footer","min_relevance":"medium","max_videos":1}],"amp_video_page":[{"name":"related","min_relevance":"low","max_videos":8}],"desktop_video_page":[{"name":"series_related","min_relevance":"low","max_videos":8,"series":true},{"name":"related","min_relevance":"low","max_videos":8}],"desktop_article_page":[{"name":"carousel","min_relevance":"low","max_videos":5}],"mobile_article_page":[{"name":"carousel","min_relevance":"low","max_videos":5}],"desktop_album_page":[{"name":"sidebar","min_relevance":"medium","fringe_min_relevance":"low","max_videos":1}],"amp ...
#   </script>
#   <img height="0" src="https://loadus.exelator.com/load/?g=4&amp;j=0&amp;p=1183&amp;page-type=song&amp;user_signed_in=false" style="display: block;" width="0"/>
#   <script type="text/javascript">
#    _qevents.push({ qacct: "p-f3CPQ6vHckedE"});
#   </script>
#   <noscript>
#    <div style="display: none;">
#     <img alt="Quantcast" height="1" src="http://pixel.quantserve.com/pixel/p-f3CPQ6vHckedE.gif" width="1">
#     </img>
#    </div>
#   </noscript>
#   <script type="text/javascript">
#    var _sf_async_config={};
#
#   _sf_async_config.uid = 3877;
#   _sf_async_config.domain = 'genius.com';
#   _sf_async_config.title = 'Snoop Dogg – Drop It Like It\'s Hot Lyrics | Genius Lyrics';
#   _sf_async_config.sections = 'songs,tag:rap';
#   _sf_async_config.authors = 'Snoop Dogg,Pharrell Williams';
#
#   var _cbq = window._cbq || [];
#
#   (function(){
#     function loadChartbeat() {
#       window._sf_endpt=(new Date()).getTime();
#       var e = document.createElement('script');
#       e.setAttribute('language', 'javascript');
#       e.setAttribute('type', 'text/javascript');
#       e.setAttribute('src', 'https://static.chartbeat.com/js/chartbeat.js');
#       document.body.appendChild(e);
#     }
#     var oldonload = window.onload;
#     window.onload = (typeof window.onload != 'function') ?
#        loadChartbeat : function() { oldonload(); loadChartbeat(); };
#   })();
#   </script>
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "17151659" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#   </script>
#   <noscript>
#    <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=17151659&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- End comScore Tag -->
#   <script>
#    !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '201983886890479');
#   fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=201983886890479&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </body>
# </html>

# %%
response = requests.get("https://genius.com/Snoop-dogg-drop-it-like-its-hot-lyrics")
print(response.status_code)
soup = bs4.BeautifulSoup(response.content, "html.parser")
description = soup.find("meta", property="og:description")
result = "We couldn't find much buzz about this song :(" if description is None else re.sub(r'^https?:\/\/.*[\r\n]*', '', description['content'], flags=re.MULTILINE)
print(result)
# Out:
# 200
# The phrase “Drop it like it’s hot” existed in hip-hop for many years before this song—but Snoop and Pharrell undoubtedly brought it to new heights when this became Snoop’s first

# %%
response = requests.get("https://genius.com/Snoop-dogg-drop-it-like-its-hot-lyrics")
print(response.status_code)
soup = bs4.BeautifulSoup(response.content, "html.parser")
comment = soup.find("div", {"class": "ikywhQ"}) #about box
result = "We couldn't find much buzz about this song :(" if comment is None else re.sub(r'^https?:\/\/.*[\r\n]*', '', comment.getText(), flags=re.MULTILINE)
print(result)
# Out:
# 200
# The phrase “Drop it like it’s hot” existed in hip-hop for many years before this song—but Snoop and Pharrell undoubtedly brought it to new heights when this became Snoop’s first ever #1 hit on Billboard.
# Snoop and Pharrell recalled the making of this song on GGN including how Pharrell came up with the hook, what inspired the spray can sound on the beat, how P made Snoop rewrite his second verse, and how Chad Hugo added the synth drop to the beat:
# Everyone from Lil Flip to Positive K to Jay Z had used the phrase on songs before this came out, but it was made famous by a 17-year-old Lil Wayne when he uttered it on Juvenile’s 1999 smash “Back That Azz Up.” Lil Wayne later responded to this song with “Nah This Ain’t The Remix” by remaking the hook, and admitting to being a “little upset” before ultimately giving Snoop his props by paraphrasing a line from Jay Z’s “Takeover”
# Nah, I ain’t a hater, don’t get me wrong
# I made it a hot line, you made it a hot song
# This song was released as a playable track in the Rock Band game series, albeit as an alternate rock remix to better fit with the game setting.

# %%
response = requests.get("https://www.songfacts.com/facts/snoop-dogg/drop-it-like-its-hot")
print(response.status_code)
soup = bs4.BeautifulSoup(response.content, "html.parser")
comment = soup.find("ul", {"class": "songfacts-results"})
result = "We couldn't find much buzz about this song :(" if comment is None else comment.getText()
print(result)

print(soup.prettify())
# Out:
# 200
# We couldn't find much buzz about this song :(
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    ShieldSquare Captcha
#   </title>
#   <script type="text/javascript">
#    window.SSJSInternal = 1055;
#
# 	(function(w, d, e, u, c, g, a, b){
# 		w["SSJSConnectorObj"] = w["SSJSConnectorObj"] || {ss_cid : c, domain_info: g};
# 		a = d.createElement(e);
# 		a.async = true;
# 		a.src = u;
# 		b = d.getElementsByTagName(e)[0];
# 		b.parentNode.insertBefore(a, b);
# 	})(window,document,"script","https://cdn.perfdrive.com/aperture/aperture.js","b8c3","auto");
#   </script>
#  </head>
#  <body>
#   <link href="http://captcha.perfdrive.com/captcha-public/css/shieldsquare_styles.min.css" rel="stylesheet" type="text/css"/>
#   <div class="container">
#    <div class="row">
#     <div class="col-1">
#      <img alt="" src="https://www.songfacts.com/img-blogimg-350-3562.jpg"/>
#     </div>
#     <div class="col-2">
#      <h1>
#       Hey, our system thinks you're a bot.
#      </h1>
#      <p>
#       This could be because you're using an anonymous Private/Proxy network, or because suspicious activity came from somewhere in your network at some point. Anyway, please solve the CAPTCHA below and you should be on your way to Songfacts. Sorry for the inconvenience.
#       <br/>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div>
#      <center>
#      </center>
#     </div>
#     <br/>
#     <div class="captcha-mid">
#      <!-- *Required - Uncomment the below commented php code and remove 'echo 1234' before submit -->
#      <form action="" method="POST" style="width:300px;margin-left:auto;margin-right:auto;">
#       <script src="https://www.google.com/recaptcha/api.js?hl=en" type="text/javascript">
#       </script>
#       <div class="g-recaptcha" data-sitekey="6LeH3loUAAAAAI_m15sXabjr8-Iqj2yI3F3JeK8X">
#       </div>
#       <input id="recaptcha_response" name="recaptcha_response" type="hidden"/>
#       <br/>
#       <center>
#        <br/>
#        <input class="btn btn-success btn-sm" type="submit" value="Submit"/>
#        <br/>
#       </center>
#      </form>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

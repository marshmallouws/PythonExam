# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.cluster import MeanShift
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("data/song_data.csv")

# %%
data.head()
# Out:
#                     song_name  song_popularity  song_duration_ms  \
# 0  Boulevard of Broken Dreams               73            262333
# 1                  In The End               66            216933
# 2           Seven Nation Army               76            231733
# 3                  By The Way               74            216933
# 4           How You Remind Me               56            223826
#
#    acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0      0.005520         0.496   0.682          0.000029    8    0.0589
# 1      0.010300         0.542   0.853          0.000000    3    0.1080
# 2      0.008170         0.737   0.463          0.447000    0    0.2550
# 3      0.026400         0.451   0.970          0.003550    0    0.1020
# 4      0.000954         0.447   0.766          0.000000   10    0.1130
#
#    loudness  audio_mode  speechiness    tempo  time_signature  audio_valence
# 0    -4.095           1       0.0294  167.060               4          0.474
# 1    -6.407           0       0.0498  105.256               4          0.370
# 2    -7.828           1       0.0792  123.881               4          0.324
# 3    -4.938           1       0.1070  122.444               4          0.198
# 4    -5.065           1       0.0313  172.011               4          0.574

# %%
kmeans = KMeans(n_clusters=300)

# %%
kmeans.fit(data.drop('song_name',axis=1))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=300, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[4.70138889e+01, 1.77900833e+05, 2.48572952e-01, ...,
#         1.27876097e+02, 3.98611111e+00, 6.21684722e-01],
#        [5.36250000e+01, 2.78461153e+05, 2.34223931e-01, ...,
#         1.15089569e+02, 3.94444444e+00, 5.27730556e-01],
#        [3.79230769e+01, 3.72469231e+05, 2.61103615e-01, ...,
#         1.10579308e+02, 3.92307692e+00, 4.52130769e-01],
#        ...,
#        [4.40000000e+01, 4.63868000e+05, 5.92880000e-03, ...,
#         1.29017000e+02, 4.00000000e+00, 3.68150000e-01],
#        [4.34090909e+01, 1.36573432e+05, 4.90030682e-01, ...,
#         1.36615477e+02, 3.95454545e+00, 6.38143182e-01],
#        [5.18000000e+01, 5.11044600e+05, 2.38412600e-01, ...,
#         1.22621000e+02, 4.00000000e+00, 4.60800000e-01]])

# %%
info = pd.read_csv("data/song_info.csv")

# %%
info.groupby("playlist").nunique()
# Out:
#                            song_name  artist_name  album_names  playlist
# playlist
# 00s Rock Anthems                  60           52           57         1
# 100% LatinX                       59           57           59         1
# 2000s Smash Hits                  80           41           66         1
# 50 Latin Classics                 50           49           49         1
# 60s Rock Anthems                 100           62           92         1
# ...                              ...          ...          ...       ...
# Workout Twerkout                  49           38           47         1
# You & Me                         100           79           86         1
# Young & Free                     100           91          100         1
# Your Favorite Coffeehouse        100           97          100         1
# mint                              50           44           48         1
#
# [300 rows x 4 columns]

# %%
df = data.to_numpy()

# %%
df[:,1]
# Out:
# array([73, 66, 76, ..., 23, 55, 60], dtype=object)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df[:,1], df[:,2], c=kmeans.labels_, cmap='rainbow')

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = data.index.values
cluster_map['cluster'] = kmeans.labels_

# %%
combined_data = data.join(info.drop("song_name",axis=1)).join(cluster_map.drop("data_index",axis=1)).drop_duplicates(subset=['song_name',"artist_name","song_duration_ms"],keep="last")

# %%
combined_data[combined_data.cluster == 287].describe()
# Out:
#        song_popularity  song_duration_ms  acousticness  danceability  \
# count        61.000000         61.000000     61.000000     61.000000
# mean         48.409836     266219.836066      0.288381      0.579115
# std          19.627682        303.453741      0.289816      0.184121
# min           0.000000     265678.000000      0.000018      0.178000
# 25%          37.000000     265952.000000      0.021800      0.447000
# 50%          51.000000     266213.000000      0.187000      0.607000
# 75%          63.000000     266493.000000      0.483000      0.727000
# max          76.000000     266733.000000      0.922000      0.939000
#
#           energy  instrumentalness        key   liveness   loudness  \
# count  61.000000         61.000000  61.000000  61.000000  61.000000
# mean    0.606951          0.061623   5.606557   0.154921  -8.083590
# std     0.209316          0.173467   3.450984   0.116793   2.781233
# min     0.187000          0.000000   0.000000   0.037400 -15.762000
# 25%     0.447000          0.000000   2.000000   0.090200  -9.805000
# 50%     0.631000          0.000063   5.000000   0.104000  -8.055000
# 75%     0.757000          0.002860   9.000000   0.205000  -5.598000
# max     0.978000          0.805000  11.000000   0.703000  -2.921000
#
#        audio_mode  speechiness       tempo  time_signature  audio_valence  \
# count   61.000000    61.000000   61.000000       61.000000      61.000000
# mean     0.540984     0.105151  113.953164        3.868852       0.475126
# std      0.502453     0.111042   26.906886        0.464593       0.279324
# min      0.000000     0.027200   56.983000        1.000000       0.038500
# 25%      0.000000     0.033800   94.001000        4.000000       0.250000
# 50%      1.000000     0.044200  115.002000        4.000000       0.442000
# 75%      1.000000     0.165000  136.827000        4.000000       0.709000
# max      1.000000     0.492000  174.984000        4.000000       0.964000
#
#        cluster
# count     61.0
# mean     287.0
# std        0.0
# min      287.0
# 25%      287.0
# 50%      287.0
# 75%      287.0
# max      287.0

# %%
combined_data[combined_data.cluster == 287].sort_values(by=["song_popularity"],ascending=False).head(10)
# Out:
#                        song_name  song_popularity  song_duration_ms  \
# 8819                Little Talks               76            266600
# 10922                 Disconnect               75            265883
# 451    The Boys Are Back in Town               74            266720
# 10330                   Caraluna               73            266160
# 3148                        GOLD               72            266000
# 18752              Sense of Home               72            265840
# 2401               Runaway Train               70            265866
# 18124      Drop It Like It's Hot               70            266066
# 677     Dude (Looks Like A Lady)               69            265773
# 10395                 Suavemente               69            266306
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# 8819         0.0206         0.446   0.757          0.000000    1    0.1460
# 10922        0.5760         0.457   0.337          0.000009    6    0.1900
# 451          0.2340         0.445   0.706          0.000252    8    0.2050
# 10330        0.1760         0.760   0.773          0.000000    9    0.1000
# 3148         0.0716         0.808   0.647          0.000466   11    0.2050
# 18752        0.8920         0.565   0.207          0.000002    3    0.1020
# 2401         0.0132         0.613   0.720          0.000000    0    0.1040
# 18124        0.1870         0.881   0.622          0.000000    1    0.1030
# 677          0.4170         0.537   0.978          0.000016    4    0.0374
# 10395        0.2380         0.809   0.883          0.002340    8    0.0625
#
#        loudness  audio_mode  speechiness    tempo  time_signature  \
# 8819     -5.177           1       0.0322  102.880               4
# 10922   -10.825           0       0.1660   66.933               3
# 451      -9.803           1       0.0461   80.823               4
# 10330    -5.314           1       0.0675  102.789               4
# 3148     -6.947           0       0.1660  110.036               4
# 18752   -10.926           1       0.0320  140.068               4
# 2401     -7.957           1       0.0425  117.341               4
# 18124    -4.149           1       0.2150   91.989               4
# 677      -2.921           0       0.0442  126.343               4
# 10395    -2.965           1       0.0689  124.096               4
#
#        audio_valence          artist_name  \
# 8819          0.4210  Of Monsters and Men
# 10922         0.1840                6LACK
# 451           0.7680           Thin Lizzy
# 10330         0.8950              Bacilos
# 3148          0.2900         BROCKHAMPTON
# 18752         0.0904       Harrison Storm
# 2401          0.5610          Soul Asylum
# 18124         0.6330           Snoop Dogg
# 677           0.9310            Aerosmith
# 10395         0.9180         Elvis Crespo
#
#                                    album_names                   playlist  \
# 8819                      My Head Is An Animal                 Hit Rewind
# 10922                 East Atlanta Love Letter         Love, Sex, & Water
# 451                 Jailbreak (Deluxe Edition)           70s Rock Anthems
# 10330                           Grandes Exitos         Latin Pop Classics
# 3148                                SATURATION                   Anti Pop
# 18752                            Sense of Home  Your Favorite Coffeehouse
# 2401                       Grave Dancers Union                All Out 90s
# 18124  R&G (Rhythm & Gangsta): The Masterpiece           Way Back Workout
# 677                         Permanent Vacation           80s Rock Anthems
# 10395                  Suavemente...Los Exitos                Latin Pride
#
#        cluster
# 8819       287
# 10922      287
# 451        287
# 10330      287
# 3148       287
# 18752      287
# 2401       287
# 18124      287
# 677        287
# 10395      287
